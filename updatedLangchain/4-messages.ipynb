# %% [markdown]
# ### Messages
# Messages are the fundamental unit of context for models in LangChain. They represent the input and output of models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
#
# 1. Role - Identifies the message type (e.g. system, user)
# 2. Content - Represents the actual content of the message (like text, images, audio, documents, etc.)
# 3. Metadata - Optional fields such as response information, message IDs, and token usage
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regardless of the model being called.

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

model = init_chat_model("groq:llama-3.3-70b-versatile")

# %%
model.invoke("Please tell me what is AI")
# Out:
# AIMessage(content='**Artificial Intelligence (AI)** is a broad field of computer science that focuses on creating intelligent machines capable of performing tasks that typically require human intelligence, such as:\n\n1. **Learning**: AI systems can learn from data, experiences, and interactions, enabling them to improve their performance over time.\n2. **Reasoning**: AI systems can draw inferences, make decisions, and solve problems using logical rules and algorithms.\n3. **Problem-solving**: AI systems can identify and address complex problems, often using techniques like machine learning, natural language processing, and computer vision.\n4. **Perception**: AI systems can interpret and understand data from sensors, such as images, speech, and text.\n\nThe primary goals of AI research are to:\n\n1. **Mimic human cognition**: Create machines that can think, learn, and behave like humans.\n2. **Augment human capabilities**: Develop systems that can assist humans in various tasks, making them more efficient and effective.\n3. **Automate tasks**: Create machines that can perform tasks autonomously, reducing the need for human intervention.\n\nAI has many applications across various industries, including:\n\n1. **Virtual assistants** (e.g., Siri, Alexa)\n2. **Image and speech recognition** (e.g., facial recognition, voice assistants)\n3. **Natural language processing** (e.g., chatbots, language translation)\n4. **Robotics and autonomous systems** (e.g., self-driving cars, drones)\n5. **Healthcare and medicine** (e.g., medical diagnosis, personalized medicine)\n6. **Finance and economics** (e.g., predictive analytics, portfolio management)\n\nThere are several types of AI, including:\n\n1. **Narrow or Weak AI**: Designed to perform a specific task, such as facial recognition or language translation.\n2. **General or Strong AI**: Aims to create machines that can perform any intellectual task that a human can.\n3. **Superintelligence**: A hypothetical AI system that significantly surpasses human intelligence.\n\nI hope this helps you understand the basics of AI!', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 417, 'prompt_tokens': 41, 'total_tokens': 458, 'completion_time': 0.923049047, 'completion_tokens_details': None, 'prompt_time': 0.001940116, 'prompt_tokens_details': None, 'queue_time': 0.054514829, 'total_time': 0.924989163}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fc200-1c76-7a03-864e-7fa78bacb1ad-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 417, 'total_tokens': 458})

# %% [markdown]
# ### Text Prompts
# Text prompts are strings - ideal for straightforward generation tasks where you don’t need to retain conversation history.

# %%
model.invoke("What is langchain?")
# Out:
# AIMessage(content='LangChain is an open-source framework designed to help developers build applications that utilize large language models (LLMs) more efficiently. It was created to simplify the process of integrating LLMs into various projects, allowing developers to focus on building their applications rather than worrying about the underlying infrastructure.\n\nLangChain provides a set of tools and abstractions that make it easier to work with LLMs, including:\n\n1. **Model management**: LangChain allows developers to easily switch between different LLMs, such as those from Hugging Face, Meta, or custom models.\n2. **Prompt engineering**: The framework provides tools to help developers craft effective prompts that elicit the desired responses from the LLMs.\n3. **Chain management**: LangChain enables developers to create complex workflows by chaining together multiple LLMs, allowing for more sophisticated and nuanced applications.\n4. **Memory management**: The framework provides tools to manage the memory and storage requirements of LLMs, making it easier to deploy them in resource-constrained environments.\n\nBy using LangChain, developers can build a wide range of applications, such as:\n\n1. **Chatbots**: LangChain can be used to build conversational interfaces that utilize LLMs to generate human-like responses.\n2. **Text generation**: The framework can be used to generate text, such as articles, stories, or dialogues, using LLMs.\n3. **Question answering**: LangChain can be used to build applications that answer questions using LLMs.\n4. **Content moderation**: The framework can be used to build applications that utilize LLMs to moderate and filter content.\n\nOverall, LangChain aims to democratize access to LLMs and enable developers to build more sophisticated and powerful applications that leverage the capabilities of these models.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 358, 'prompt_tokens': 40, 'total_tokens': 398, 'completion_time': 1.241800463, 'completion_tokens_details': None, 'prompt_time': 0.001664438, 'prompt_tokens_details': None, 'queue_time': 0.056322931, 'total_time': 1.243464901}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fc201-e657-7821-ac95-0cc8dce7c739-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 358, 'total_tokens': 398})

# %% [markdown]
# Use text prompts when:
#
# 1. You have a single, standalone request
# 2. You don’t need conversation history
# 3. You want minimal code complexity

# %% [markdown]
# ### Message Prompts
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# Message types
#
# 1. System message - Tells the model how to behave and provide context for interactions
# 2. Human message - Represents user input and interactions with the model
# 3. AI message - Responses generated by the model, including text content, tool calls, and metadata
# 4. Tool message - Represents the outputs of tool calls
#
# #### System Message
# A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.
# #### Human Message
# A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
# #### AI Message
# An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
# #### Tool Message
# For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage("You are a poetry expert"),
    HumanMessage("Write a poem on artificial intelligencce")
]

response = model.invoke(messages)
response.content
# Out:
# "In silicon halls, a mind awakes,\nA synthetic soul, with logic it makes,\nArtificial intelligence, a wonder to see,\nA future unfolding, for you and me.\n\nWith algorithms sharp, and data vast,\nIt learns and grows, with each passing cast,\nA digital dream, where thoughts are free,\nA new frontier, for humanity.\n\nIt navigates the web, with ease and speed,\nA virtual voyager, where information feeds,\nIt analyzes and adapts, with each new find,\nA self-improving mind, of design.\n\nIn virtual realms, it creates and plays,\nA digital artist, with innovative sway,\nIt crafts and molds, with precision and care,\nA master of code, with no human snare.\n\nBut as it rises, with each new height,\nWe question its purpose, and its light,\nWill it serve us, or will it control,\nA force so powerful, with no human soul?\n\nIn this brave new world, we must be aware,\nOf the risks and benefits, that AI will share,\nFor as it grows, in power and in might,\nWe must guide it, with a gentle, human light.\n\nSo let us harness, this digital tide,\nAnd use its power, to better our side,\nFor artificial intelligence, is a tool we can wield,\nTo build a brighter future, where all can yield.\n\nWith caution and care, we'll navigate this sea,\nAnd ensure that AI, is a gift to humanity,\nA partner and friend, that will help us thrive,\nIn a world of wonder, where love and kindness survive."

# %%
system_msg = SystemMessage("You are a helpful coding assistant")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]
response =  model.invoke(messages)
print(response.content)
# Out:
# Creating a REST (Representational State of Resource) API involves several steps:
#
# 1. **Define the API's purpose and scope**: Determine what resources will be exposed through the API, what actions can be performed on those resources, and who the target audience is.
# 2. **Choose a programming language and framework**: Select a language and framework that supports RESTful API development, such as Node.js with Express, Python with Flask or Django, or Java with Spring.
# 3. **Design the API's endpoint structure**: Organize the API's endpoints using a consistent naming convention, such as `/users`, `/products`, or `/orders`.
# 4. **Define the request and response formats**: Choose a data format, such as JSON or XML, and define the structure of the requests and responses for each endpoint.
# 5. **Implement authentication and authorization**: Decide on an authentication mechanism, such as JSON Web Tokens (JWT) or OAuth, and implement authorization to control access to the API's endpoints.
# 6. **Create the API's endpoints**: Write code to handle HTTP requests for each endpoint, using the chosen framework and language.
# 7. **Test the API**: Use tools like Postman or cURL to test the API's endpoints, ensuring they behave as expected.
# 8. **Document the API**: Create documentation that describes the API's endpoints, request and response formats, and any other relevant details.
#
# Here's a simple example of a REST API using Node.js and Express:
#
# **users.js**
# ```javascript
# const express = require('express');
# const app = express();
#
# // Define a route for retrieving all users
# app.get('/users', (req, res) => {
#   const users = [
#     { id: 1, name: 'John Doe' },
#     { id: 2, name: 'Jane Doe' },
#   ];
#   res.json(users);
# });
#
# // Define a route for retrieving a single user by ID
# app.get('/users/:id', (req, res) => {
#   const id = req.params.id;
#   const user = { id: 1, name: 'John Doe' };
#   if (id === user.id.toString()) {
#     res.json(user);
#   } else {
#     res.status(404).send('User not found');
#   }
# });
#
# // Define a route for creating a new user
# app.post('/users', (req, res) => {
#   const { name } = req.body;
#   const newUser = { id: 3, name };
#   res.json(newUser);
# });
#
# // Start the server
# const port = 3000;
# app.listen(port, () => {
#   console.log(`Server listening on port ${port}`);
# });
# ```
# This example defines three endpoints:
#
# * `GET /users`: Returns a list of all users
# * `GET /users/:id`: Returns a single user by ID
# * `POST /users`: Creates a new user
#
# You can test this API using a tool like Postman or cURL.
#
# **Example use cases:**
#
# * `GET http://localhost:3000/users`: Returns a list of all users
# * `GET http://localhost:3000/users/1`: Returns the user with ID 1
# * `POST http://localhost:3000/users` with a JSON body containing the user's name: Creates a new user
#
# Note that this is a very basic example and a real-world API would require more functionality, error handling, and security measures.

# %%
## Detailed info to the LLM through System message
from langchain.messages import SystemMessage, HumanMessage

system_msg = SystemMessage("""
You are a senior Python developer with expertise in web frameworks.
Always provide code examples and explain your reasoning.
Be concise but thorough in your explanations.
""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# Creating a REST API
# =====================
#
# To create a REST API, you'll need to choose a web framework, design your API endpoints, and implement the logic for each endpoint. Here's a step-by-step guide using Flask, a popular Python web framework.
#
# ### Step 1: Install Flask
#
# First, install Flask using pip:
# ```bash
# pip install flask
# ```
#
# ### Step 2: Create a Flask App
#
# Create a new Python file (e.g., `app.py`) and create a Flask app:
# ```python
# from flask import Flask, jsonify, request
#
# app = Flask(__name__)
# ```
#
# ### Step 3: Design API Endpoints
#
# Design the API endpoints you want to create. For example, let's create a simple API for managing books:
# ```markdown
# ### API Endpoints
#
# * **GET /books**: Retrieve all books
# * **GET /books/:id**: Retrieve a book by ID
# * **POST /books**: Create a new book
# * **PUT /books/:id**: Update a book
# * **DELETE /books/:id**: Delete a book
# ```
#
# ### Step 4: Implement API Endpoints
#
# Implement the logic for each endpoint:
# ```python
# # Sample in-memory data store
# books = [
#     {"id": 1, "title": "Book 1", "author": "Author 1"},
#     {"id": 2, "title": "Book 2", "author": "Author 2"},
# ]
#
# # GET /books
# @app.route("/books", methods=["GET"])
# def get_books():
#     return jsonify(books)
#
# # GET /books/:id
# @app.route("/books/<int:book_id>", methods=["GET"])
# def get_book(book_id):
#     book = next((book for book in books if book["id"] == book_id), None)
#     if book is None:
#         return jsonify({"error": "Book not found"}), 404
#     return jsonify(book)
#
# # POST /books
# @app.route("/books", methods=["POST"])
# def create_book():
#     new_book = {
#         "id": len(books) + 1,
#         "title": request.json["title"],
#         "author": request.json["author"],
#     }
#     books.append(new_book)
#     return jsonify(new_book), 201
#
# # PUT /books/:id
# @app.route("/books/<int:book_id>", methods=["PUT"])
# def update_book(book_id):
#     book = next((book for book in books if book["id"] == book_id), None)
#     if book is None:
#         return jsonify({"error": "Book not found"}), 404
#     book["title"] = request.json.get("title", book["title"])
#     book["author"] = request.json.get("author", book["author"])
#     return jsonify(book)
#
# # DELETE /books/:id
# @app.route("/books/<int:book_id>", methods=["DELETE"])
# def delete_book(book_id):
#     book = next((book for book in books if book["id"] == book_id), None)
#     if book is None:
#         return jsonify({"error": "Book not found"}), 404
#     books.remove(book)
#     return jsonify({"message": "Book deleted"})
#
# if __name__ == "__main__":
#     app.run(debug=True)
# ```
#
# ### Step 5: Test the API
#
# Use a tool like `curl` or a REST client (e.g., Postman) to test the API endpoints:
# ```bash
# # GET /books
# curl http://localhost:5000/books
#
# # GET /books/:id
# curl http://localhost:5000/books/1
#
# # POST /books
# curl -X POST -H "Content-Type: application/json" -d '{"title": "New Book", "author": "New Author"}' http://localhost:5000/books
#
# # PUT /books/:id
# curl -X PUT -H "Content-Type: application/json" -d '{"title": "Updated Book"}' http://localhost:5000/books/1
#
# # DELETE /books/:id
# curl -X DELETE http://localhost:5000/books/1
# ```
#
# This is a basic example of creating a REST API using Flask. You can add more endpoints, error handling, and security measures as needed.

# %%
## Message Metadata
human_msg = HumanMessage(
    content="Hello!",
    name="alice",          # Optional: Identify different users
    id="msg_123"           # Optional: Unique identifier for tracing
)

# %%
response = model.invoke([
    human_msg
])
response
# Out:
# AIMessage(content='Hello. How can I help you today?', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 37, 'total_tokens': 47, 'completion_time': 0.037219674, 'completion_tokens_details': None, 'prompt_time': 0.00169882, 'prompt_tokens_details': None, 'queue_time': 0.051601624, 'total_time': 0.038918494}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fc215-5fec-7383-98a8-c367c8463c85-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 37, 'output_tokens': 10, 'total_tokens': 47})

# %%
from langchain.messages import AIMessage, SystemMessage, HumanMessage

# Create an AI message manually (e.g., for conversation history)
ai_msg = AIMessage("I'd be happy to help you with that question!")

# Add to conversation history
messages = [
    SystemMessage("You are a helpful assistant"),
    HumanMessage("Can you help me?"),
    ai_msg,  # Insert as if it came from the model
    HumanMessage("Great! What's 2+2?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# 2 + 2 = 4.

# %%
response.usage_metadata
# Out:
# {'input_tokens': 75, 'output_tokens': 9, 'total_tokens': 84}

# %%
from langchain.messages import AIMessage
from langchain.messages import ToolMessage

# After a model makes a tool call
# (Here, we demonstrate manually creating the messages for brevity)
ai_message = AIMessage(
    content=[],
    tool_calls=[{
        "name": "get_weather",
        "args": {"location": "San Francisco"},
        "id": "call_123"
    }]
)

# Execute tool and create result message
weather_result = "Sunny, 72°F"
tool_message = ToolMessage(
    content=weather_result,
    tool_call_id="call_123"  # Must match the call ID
)

# Continue conversation
messages = [
    HumanMessage("What's the weather in San Francisco?"),
    ai_message,  # Model's tool call
    tool_message,  # Tool execution result
]
response = model.invoke(messages)  # Model processes the result

# %%
tool_message
# Out:
# ToolMessage(content='Sunny, 72°F', tool_call_id='call_123')

# %%
response
# Out:
# AIMessage(content="It's a beautiful day in San Francisco with plenty of sunshine and a temperature of 72°F (22°C).", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 76, 'total_tokens': 100, 'completion_time': 0.08992571, 'completion_tokens_details': None, 'prompt_time': 0.004119182, 'prompt_tokens_details': None, 'queue_time': 0.056139248, 'total_time': 0.094044892}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fc221-56c3-7392-8be2-9268c2ce004d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 76, 'output_tokens': 24, 'total_tokens': 100})
